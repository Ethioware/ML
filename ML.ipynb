# %% [markdown]
# <a href="https://colab.research.google.com/github/Ethioware/ML/blob/main/ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
#    Grade  Age  Gender I’m excited to attend school every day.  \
# 0     11   18  Female                                Not sure
# 1     11   18    Male                                Not sure
# 2      9   16  Female                       I agree very much
# 3      9   15  Female                                 I agree
# 4      9   15  Female                                 I agree
#
#   The Intensity of my courses has a negative effect on my motivation to learn.  \
# 0                                            I agree
# 1                                            I agree
# 2                                         I disagree
# 3                                         I disagree
# 4                                         I disagree
#
#   My teachers are qualified to teach their course.  \
# 0                                         Not sure
# 1                                         Not sure
# 2                                I agree very much
# ...

# %%
col = ["grade", "age", "gender", "intensity", "T-qualification", "school envt","insuficient base", "lack of parental support", "ouside envt", "status", "peer motivation", "lack indiv attention", "full day", "exam validity", "parental expectation", "social media", "T-motivation", "found purpose", "academia idol"]
df = pd.read_csv("stu.csv", names = col)
df.head()
# Out:
#       grade     age                                   gender  \
# Grade   Age  Gender  I’m excited to attend school every day.
# 11       18  Female                                 Not sure
# 11       18    Male                                 Not sure
# 9        16  Female                        I agree very much
# 9        15  Female                                  I agree
#
#                                                intensity  \
# Grade  The Intensity of my courses has a negative eff...
# 11                                               I agree
# 11                                               I agree
# 9                                             I disagree
# 9                                             I disagree
#
#                                         T-qualification  \
# Grade  My teachers are qualified to teach their course.
# 11                                             Not sure
# 11                                             Not sure
# ...
