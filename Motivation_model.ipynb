# %% [markdown]
# <a href="https://colab.research.google.com/github/Ethioware/ML/blob/main/Motivation_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import necessary libraries and classes
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report

# Loaded the survey data into a pandas DataFrame
data = pd.read_csv('Survey.csv')

# %%
# pre-processing data
df = pd.DataFrame(data)
df.drop('Timestamp', axis=1, inplace=True)
df.drop('Email address', axis=1, inplace=True)
# common behaviour of students based on usage frequency
arranged = df.groupby('How often do you use educational technologies?')
arranged.median()
df
# Out:
# <ipython-input-33-aa1d1b3ca733>:7: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   arranged.median()
#    Do you wish to participate?   \
# 0                           Yes
# 1                           Yes
# 2                           Yes
# 3                           Yes
# 4                           Yes
# 5                           Yes
# 6                           Yes
# 7                           Yes
# 8                           Yes
# 9                           Yes
# 10                          Yes
# 11                          Yes
# 12                          Yes
# 13                          Yes
# 14                          Yes
# 15                          Yes
# 16                          Yes
# 17                          Yes
# 18                          Yes
# ...

# %%
# visualize the relation b/n usage and related factors
y = df['How do you rate your academic motivation in general?']
x = df['High school category:']
plt.xlabel('School Type')
plt.ylabel('Motivation level')
plt.plot(x,y)
